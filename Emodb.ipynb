# %% [markdown]
# <a href="https://colab.research.google.com/github/Anirudhan2024/Speech_Emotion_Recognition/blob/main/Emodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Run this cell only ONCE per session ---

# 1. Install Dependencies
print("Installing required libraries...")
# !pip install -q resampy audiomentations
print("✅ Installation complete.")

# 2. Import Libraries
import os
import zipfile
import librosa
import numpy as np
import time
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Conv1D, MaxPooling1D, LSTM
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# 3. Mount Google Drive
print("\nMounting Google Drive...")
try:
    drive.mount('/content/drive', force_remount=True)
    print("✅ Drive mounted successfully.")
except Exception as e:
    print(f"🚨 Error mounting drive: {e}")
    raise
# Out:
# Installing required libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 9.9 MB/s eta 0:00:00
# ✅ Installation complete.
#
# Mounting Google Drive...
# Mounted at /content/drive
# ✅ Drive mounted successfully.

# %%
# 4. Unzip the Dataset
zip_file_path = '/content/drive/MyDrive/archive.zip'
extract_dir = '/content/drive/MyDrive/EMO-DB/wav/'

print(f"\nUnzipping '{zip_file_path}'...")
if not os.path.exists(extract_dir):
    try:
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall('/content/drive/MyDrive/EMO-DB/')
        print("✅ Unzipping complete.")
    except FileNotFoundError:
        print(f"🚨 ERROR: The file '{zip_file_path}' was not found.")
        raise
else:
    print("✅ Dataset already unzipped.")

# 5. Confirm Dataset Path
def find_dataset_folder(base_path):
    for dirpath, dirnames, filenames in os.walk(base_path):
        if any(f.endswith('.wav') for f in filenames):
            print(f"✅ Found audio files in: {dirpath}")
            return dirpath
    return None

DATA_PATH = find_dataset_folder(extract_dir)
if DATA_PATH is None:
    print("🚨 ERROR: Could not locate the EMO-DB dataset folder.")
    raise FileNotFoundError("Dataset folder not found.")
# Out:
# Unzipping '/content/drive/MyDrive/archive.zip'...
# ✅ Unzipping complete.
# ✅ Found audio files in: /content/drive/MyDrive/EMO-DB/wav/

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import tqdm

# Define augmentation pipeline
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_shift=-0.5, max_shift=0.5, p=0.5),
])

# Load raw data
def load_raw_data(data_path):
    raw_data = []
    labels = []
    # EMO-DB emotion map
    emotion_map = {
        'W': 'angry',
        'L': 'boredom',
        'E': 'disgust',
        'A': 'fearful',
        'F': 'happy',
        'T': 'sad',
        'N': 'neutral'
    }

    print("\nLoading raw audio files from EMO-DB...")
    global initial_sample_rate
    initial_sample_rate = None

    all_files = []
    for root, _, files in os.walk(data_path):
        for file_name in files:
            if file_name.endswith('.wav'):
                all_files.append(os.path.join(root, file_name))

    if not all_files:
        print(f"🚨 ERROR: No .wav files found in {data_path}.")
        return [], []

    print(f"Found {len(all_files)} .wav files. Processing...")

    for file_path in tqdm.tqdm(all_files, desc="Processing audio files"):
        try:
            file_name = os.path.basename(file_path)
            if len(file_name) < 6:
                continue
            emotion_code = file_name[5]  # e.g., '03a01Wa.wav' -> 'W'
            if emotion_code not in emotion_map:
                continue

            emotion = emotion_map[emotion_code]
            audio_data, sample_rate = librosa.load(file_path, sr=None)
            if initial_sample_rate is None:
                initial_sample_rate = sample_rate

            raw_data.append(audio_data)
            labels.append(emotion)
        except Exception as e:
            print(f"\nWarning: Skipping {file_name} due to error: {e}")
            continue

    print(f"\n✅ Loaded {len(raw_data)} valid audio files.")
    return raw_data, np.array(labels)

# Load dataset
X_raw, y_raw = load_raw_data(DATA_PATH)
if len(X_raw) == 0:
    raise ValueError("No audio data was loaded. Please check your dataset path.")
# Out:
# Loading raw audio files from EMO-DB...
# Found 535 .wav files. Processing...
# Processing audio files: 100%|██████████| 535/535 [00:22<00:00, 23.54it/s]
# ✅ Loaded 535 valid audio files.

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Label encode
le = LabelEncoder()
y_encoded = le.fit_transform(y_raw)
y_categorical = to_categorical(y_encoded)

# Split
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_raw, y_categorical, test_size=0.2, random_state=42, stratify=y_categorical
)

# Apply augmentation
print("\nAugmenting training data...")
X_train_augmented_audio = []
y_train_augmented = []
for i, audio in tqdm.tqdm(enumerate(X_train_raw), total=len(X_train_raw), desc="Augmenting training data"):
    X_train_augmented_audio.append(audio)
    y_train_augmented.append(y_train[i])
    augmented_audio = augment(samples=audio, sample_rate=initial_sample_rate)
    X_train_augmented_audio.append(augmented_audio)
    y_train_augmented.append(y_train[i])
print(f"✅ Augmentation complete. Training set size: {len(X_train_augmented_audio)} samples.")

# Extract MFCC features
def extract_features(audio_list):
    feature_list = []
    for audio in tqdm.tqdm(audio_list, desc="Extracting features"):
        mfccs = librosa.feature.mfcc(y=audio, sr=initial_sample_rate, n_mfcc=40)
        feature_list.append(mfccs)
    return feature_list

print("\nExtracting MFCC features...")
X_train_features = extract_features(X_train_augmented_audio)
X_test_features = extract_features(X_test_raw)

# Pad sequences
max_pad_len = max(x.shape[1] for x in X_train_features + X_test_features)

def pad_features(features, max_len):
    return np.array([np.pad(feat, ((0, 0), (0, max_len - feat.shape[1])), mode='constant') for feat in features])

print("Padding features...")
X_train_padded = pad_features(X_train_features, max_pad_len).transpose((0, 2, 1))
X_test_padded = pad_features(X_test_features, max_pad_len).transpose((0, 2, 1))
y_train_augmented = np.array(y_train_augmented)

print("✅ Data ready for model training.")
print(f"Train shape: {X_train_padded.shape}, Test shape: {X_test_padded.shape}")
# Out:
# Augmenting training data...
# Augmenting training data: 100%|██████████| 428/428 [00:08<00:00, 48.99it/s]
# ✅ Augmentation complete. Training set size: 856 samples.
#
# Extracting MFCC features...
# Extracting features: 100%|██████████| 856/856 [00:09<00:00, 89.40it/s]
# Extracting features: 100%|██████████| 107/107 [00:00<00:00, 113.78it/s]
# Padding features...
# ✅ Data ready for model training.
# Train shape: (856, 281, 40), Test shape: (107, 281, 40)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization

# Model architecture
model = Sequential([
    Conv1D(1024, 5, padding='same', input_shape=(X_train_padded.shape[1], X_train_padded.shape[2])),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.3), # Increased dropout

    Conv1D(1024, 5, padding='same'),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.3), # Increased dropout

    Conv1D(512, 5, padding='same'),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.3), # Increased dropout

    LSTM(128),
    Dropout(0.4), # Increased dropout

    Dense(y_categorical.shape[1], activation='softmax')
])
model.summary()

# Compile
opt = Adam(learning_rate=0.00005) # Reduced learning rate
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint('best_model_emodb.keras', save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=False, verbose=1) # Increased patience, changed restore_best_weights to False
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.000001, verbose=1) # Added ReduceLROnPlateau

# Train
print("\n--- Training on EMO-DB dataset ---")
history = model.fit(
    X_train_padded, y_train_augmented,
    batch_size=32,
    epochs=200, # Increased epochs
    validation_data=(X_test_padded, y_test),
    callbacks=[checkpoint, early_stop, reduce_lr], # Added ReduceLROnPlateau to callbacks
    verbose=2
)
print("--- Training finished ---")

# Evaluate
score = model.evaluate(X_test_padded, y_test, verbose=0)
print(f"✅ Final Test Accuracy: {score[1]*100:.2f}%")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 281, 1024)      │       205,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 281, 1024)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 281, 1024)      │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 70, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 70, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 70, 1024)       │     5,243,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 70, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 70, 1024)       │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 17, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 17, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 17, 512)        │     2,621,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 17, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 17, 512)        │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 4, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,411,015 (32.09 MB)
#  Trainable params: 8,405,895 (32.07 MB)
#  Non-trainable params: 5,120 (20.00 KB)
# --- Training on EMO-DB dataset ---
# Epoch 1/200
#
# Epoch 1: val_accuracy improved from -inf to 0.19626, saving model to best_model_emodb.keras
# 27/27 - 73s - 3s/step - accuracy: 0.2512 - loss: 1.8718 - val_accuracy: 0.1963 - val_loss: 1.8280 - learning_rate: 5.0000e-05
# Epoch 2/200
#
# Epoch 2: val_accuracy improved from 0.19626 to 0.39252, saving model to best_model_emodb.keras
# 27/27 - 81s - 3s/step - accuracy: 0.3586 - loss: 1.6800 - val_accuracy: 0.3925 - val_loss: 1.6404 - learning_rate: 5.0000e-05
# Epoch 3/200
#
# Epoch 3: val_accuracy improved from 0.39252 to 0.45794, saving model to best_model_emodb.keras
# 27/27 - 70s - 3s/step - accuracy: 0.4065 - loss: 1.5535 - val_accuracy: 0.4579 - val_loss: 1.4743 - learning_rate: 5.0000e-05
# Epoch 4/200
#
# Epoch 4: val_accuracy did not improve from 0.45794
# 27/27 - 80s - 3s/step - accuracy: 0.4498 - loss: 1.4248 - val_accuracy: 0.4112 - val_loss: 1.3812 - learning_rate: 5.0000e-05
# Epoch 5/200
#
# Epoch 5: val_accuracy did not improve from 0.45794
# 27/27 - 83s - 3s/step - accuracy: 0.4918 - loss: 1.3167 - val_accuracy: 0.4299 - val_loss: 1.3371 - learning_rate: 5.0000e-05
# Epoch 6/200
#
# Epoch 6: val_accuracy improved from 0.45794 to 0.47664, saving model to best_model_emodb.keras
# 27/27 - 69s - 3s/step - accuracy: 0.5245 - loss: 1.2472 - val_accuracy: 0.4766 - val_loss: 1.2578 - learning_rate: 5.0000e-05
# Epoch 7/200
#
# Epoch 7: val_accuracy improved from 0.47664 to 0.51402, saving model to best_model_emodb.keras
# 27/27 - 80s - 3s/step - accuracy: 0.5619 - loss: 1.1838 - val_accuracy: 0.5140 - val_loss: 1.1930 - learning_rate: 5.0000e-05
# Epoch 8/200
#
# Epoch 8: val_accuracy did not improve from 0.51402
# 27/27 - 83s - 3s/step - accuracy: 0.5666 - loss: 1.1440 - val_accuracy: 0.4860 - val_loss: 1.1637 - learning_rate: 5.0000e-05
# Epoch 9/200
#
# Epoch 9: val_accuracy improved from 0.51402 to 0.56075, saving model to best_model_emodb.keras
# 27/27 - 68s - 3s/step - accuracy: 0.6098 - loss: 1.0719 - val_accuracy: 0.5607 - val_loss: 1.1210 - learning_rate: 5.0000e-05
# Epoch 10/200
#
# Epoch 10: val_accuracy did not improve from 0.56075
# 27/27 - 79s - 3s/step - accuracy: 0.6262 - loss: 1.0138 - val_accuracy: 0.5514 - val_loss: 1.0892 - learning_rate: 5.0000e-05
# Epoch 11/200
#
# Epoch 11: val_accuracy did not improve from 0.56075
# 27/27 - 67s - 2s/step - accuracy: 0.6484 - loss: 0.9316 - val_accuracy: 0.5421 - val_loss: 1.0508 - learning_rate: 5.0000e-05
# Epoch 12/200
#
# Epoch 12: val_accuracy improved from 0.56075 to 0.57009, saving model to best_model_emodb.keras
# 27/27 - 66s - 2s/step - accuracy: 0.6729 - loss: 0.9049 - val_accuracy: 0.5701 - val_loss: 0.9866 - learning_rate: 5.0000e-05
# Epoch 13/200
#
# Epoch 13: val_accuracy improved from 0.57009 to 0.60748, saving model to best_model_emodb.keras
# 27/27 - 68s - 3s/step - accuracy: 0.7033 - loss: 0.8459 - val_accuracy: 0.6075 - val_loss: 0.8813 - learning_rate: 5.0000e-05
# Epoch 14/200
#
# Epoch 14: val_accuracy improved from 0.60748 to 0.63551, saving model to best_model_emodb.keras
# 27/27 - 80s - 3s/step - accuracy: 0.7009 - loss: 0.8490 - val_accuracy: 0.6355 - val_loss: 0.8239 - learning_rate: 5.0000e-05
# Epoch 15/200
#
# Epoch 15: val_accuracy did not improve from 0.63551
# 27/27 - 68s - 3s/step - accuracy: 0.7360 - loss: 0.7580 - val_accuracy: 0.5981 - val_loss: 0.8659 - learning_rate: 5.0000e-05
# Epoch 16/200
#
# Epoch 16: val_accuracy improved from 0.63551 to 0.64486, saving model to best_model_emodb.keras
# 27/27 - 83s - 3s/step - accuracy: 0.7278 - loss: 0.7668 - val_accuracy: 0.6449 - val_loss: 0.7951 - learning_rate: 5.0000e-05
# Epoch 17/200
#
# Epoch 17: val_accuracy improved from 0.64486 to 0.67290, saving model to best_model_emodb.keras
# 27/27 - 66s - 2s/step - accuracy: 0.7710 - loss: 0.6785 - val_accuracy: 0.6729 - val_loss: 0.7863 - learning_rate: 5.0000e-05
# Epoch 18/200
#
# Epoch 18: val_accuracy improved from 0.67290 to 0.68224, saving model to best_model_emodb.keras
# 27/27 - 68s - 3s/step - accuracy: 0.7839 - loss: 0.6482 - val_accuracy: 0.6822 - val_loss: 0.7263 - learning_rate: 5.0000e-05
# Epoch 19/200
#
# Epoch 19: val_accuracy improved from 0.68224 to 0.71028, saving model to best_model_emodb.keras
# 27/27 - 81s - 3s/step - accuracy: 0.8166 - loss: 0.6028 - val_accuracy: 0.7103 - val_loss: 0.6873 - learning_rate: 5.0000e-05
# Epoch 20/200
#
# Epoch 20: val_accuracy improved from 0.71028 to 0.73832, saving model to best_model_emodb.keras
# 27/27 - 81s - 3s/step - accuracy: 0.8259 - loss: 0.5416 - val_accuracy: 0.7383 - val_loss: 0.6630 - learning_rate: 5.0000e-05
# Epoch 21/200
#
# Epoch 21: val_accuracy did not improve from 0.73832
# 27/27 - 80s - 3s/step - accuracy: 0.8201 - loss: 0.5541 - val_accuracy: 0.7383 - val_loss: 0.6593 - learning_rate: 5.0000e-05
# Epoch 22/200
#
# Epoch 22: val_accuracy improved from 0.73832 to 0.77570, saving model to best_model_emodb.keras
# 27/27 - 65s - 2s/step - accuracy: 0.8586 - loss: 0.4839 - val_accuracy: 0.7757 - val_loss: 0.5807 - learning_rate: 5.0000e-05
# Epoch 23/200
#
# Epoch 23: val_accuracy did not improve from 0.77570
# 27/27 - 82s - 3s/step - accuracy: 0.8727 - loss: 0.4400 - val_accuracy: 0.7290 - val_loss: 0.5871 - learning_rate: 5.0000e-05
# Epoch 24/200
#
# Epoch 24: val_accuracy improved from 0.77570 to 0.78505, saving model to best_model_emodb.keras
# 27/27 - 67s - 2s/step - accuracy: 0.8797 - loss: 0.4239 - val_accuracy: 0.7850 - val_loss: 0.5725 - learning_rate: 5.0000e-05
# Epoch 25/200
#
# Epoch 25: val_accuracy did not improve from 0.78505
# 27/27 - 80s - 3s/step - accuracy: 0.8879 - loss: 0.3752 - val_accuracy: 0.7477 - val_loss: 0.5850 - learning_rate: 5.0000e-05
# Epoch 26/200
#
# Epoch 26: val_accuracy improved from 0.78505 to 0.81308, saving model to best_model_emodb.keras
# 27/27 - 67s - 2s/step - accuracy: 0.9030 - loss: 0.3485 - val_accuracy: 0.8131 - val_loss: 0.5080 - learning_rate: 5.0000e-05
# Epoch 27/200
#
# Epoch 27: val_accuracy did not improve from 0.81308
# 27/27 - 66s - 2s/step - accuracy: 0.9077 - loss: 0.3365 - val_accuracy: 0.7757 - val_loss: 0.5029 - learning_rate: 5.0000e-05
# Epoch 28/200
#
# Epoch 28: val_accuracy did not improve from 0.81308
# 27/27 - 67s - 2s/step - accuracy: 0.9393 - loss: 0.2870 - val_accuracy: 0.8037 - val_loss: 0.5027 - learning_rate: 5.0000e-05
# Epoch 29/200
#
# Epoch 29: val_accuracy did not improve from 0.81308
# 27/27 - 67s - 2s/step - accuracy: 0.9252 - loss: 0.2800 - val_accuracy: 0.8037 - val_loss: 0.4971 - learning_rate: 5.0000e-05
# Epoch 30/200
#
# Epoch 30: val_accuracy did not improve from 0.81308
# 27/27 - 80s - 3s/step - accuracy: 0.9299 - loss: 0.2656 - val_accuracy: 0.8037 - val_loss: 0.4930 - learning_rate: 5.0000e-05
# Epoch 31/200
#
# Epoch 31: val_accuracy improved from 0.81308 to 0.82243, saving model to best_model_emodb.keras
# 27/27 - 67s - 2s/step - accuracy: 0.9568 - loss: 0.2342 - val_accuracy: 0.8224 - val_loss: 0.4624 - learning_rate: 5.0000e-05
# Epoch 32/200
#
# Epoch 32: val_accuracy improved from 0.82243 to 0.83178, saving model to best_model_emodb.keras
# 27/27 - 67s - 2s/step - accuracy: 0.9439 - loss: 0.2207 - val_accuracy: 0.8318 - val_loss: 0.4323 - learning_rate: 5.0000e-05
# Epoch 33/200
#
# Epoch 33: val_accuracy improved from 0.83178 to 0.85047, saving model to best_model_emodb.keras
# 27/27 - 81s - 3s/step - accuracy: 0.9509 - loss: 0.1948 - val_accuracy: 0.8505 - val_loss: 0.4292 - learning_rate: 5.0000e-05
# Epoch 34/200
#
# Epoch 34: val_accuracy did not improve from 0.85047
# 27/27 - 67s - 2s/step - accuracy: 0.9509 - loss: 0.1861 - val_accuracy: 0.8318 - val_loss: 0.4611 - learning_rate: 5.0000e-05
# Epoch 35/200
#
# Epoch 35: val_accuracy did not improve from 0.85047
# 27/27 - 82s - 3s/step - accuracy: 0.9626 - loss: 0.1707 - val_accuracy: 0.8411 - val_loss: 0.4209 - learning_rate: 5.0000e-05
# Epoch 36/200
#
# Epoch 36: val_accuracy did not improve from 0.85047
# 27/27 - 81s - 3s/step - accuracy: 0.9755 - loss: 0.1532 - val_accuracy: 0.8411 - val_loss: 0.4188 - learning_rate: 5.0000e-05
# Epoch 37/200
#
# Epoch 37: val_accuracy did not improve from 0.85047
# 27/27 - 68s - 3s/step - accuracy: 0.9778 - loss: 0.1378 - val_accuracy: 0.8318 - val_loss: 0.4216 - learning_rate: 5.0000e-05
# Epoch 38/200
#
# Epoch 38: val_accuracy did not improve from 0.85047
# 27/27 - 81s - 3s/step - accuracy: 0.9661 - loss: 0.1469 - val_accuracy: 0.8411 - val_loss: 0.4222 - learning_rate: 5.0000e-05
# Epoch 39/200
#
# Epoch 39: val_accuracy did not improve from 0.85047
# 27/27 - 68s - 3s/step - accuracy: 0.9685 - loss: 0.1257 - val_accuracy: 0.8505 - val_loss: 0.4291 - learning_rate: 5.0000e-05
# Epoch 40/200
#
# Epoch 40: val_accuracy improved from 0.85047 to 0.85981, saving model to best_model_emodb.keras
# 27/27 - 84s - 3s/step - accuracy: 0.9813 - loss: 0.1128 - val_accuracy: 0.8598 - val_loss: 0.4148 - learning_rate: 5.0000e-05
# Epoch 41/200
#
# Epoch 41: val_accuracy improved from 0.85981 to 0.87850, saving model to best_model_emodb.keras
# 27/27 - 66s - 2s/step - accuracy: 0.9801 - loss: 0.0973 - val_accuracy: 0.8785 - val_loss: 0.3534 - learning_rate: 5.0000e-05
# Epoch 42/200
#
# Epoch 42: val_accuracy did not improve from 0.87850
# 27/27 - 80s - 3s/step - accuracy: 0.9848 - loss: 0.0857 - val_accuracy: 0.8692 - val_loss: 0.3773 - learning_rate: 5.0000e-05
# Epoch 43/200
#
# Epoch 43: val_accuracy did not improve from 0.87850
# 27/27 - 83s - 3s/step - accuracy: 0.9825 - loss: 0.0997 - val_accuracy: 0.8411 - val_loss: 0.3952 - learning_rate: 5.0000e-05
# Epoch 44/200
#
# Epoch 44: val_accuracy did not improve from 0.87850
# 27/27 - 65s - 2s/step - accuracy: 0.9918 - loss: 0.0715 - val_accuracy: 0.8692 - val_loss: 0.4024 - learning_rate: 5.0000e-05
# Epoch 45/200
#
# Epoch 45: val_accuracy did not improve from 0.87850
# 27/27 - 82s - 3s/step - accuracy: 0.9836 - loss: 0.0871 - val_accuracy: 0.8692 - val_loss: 0.3638 - learning_rate: 5.0000e-05
# Epoch 46/200
#
# Epoch 46: val_accuracy did not improve from 0.87850
# 27/27 - 82s - 3s/step - accuracy: 0.9907 - loss: 0.0812 - val_accuracy: 0.8785 - val_loss: 0.3968 - learning_rate: 5.0000e-05
# Epoch 47/200
#
# Epoch 47: val_accuracy did not improve from 0.87850
# 27/27 - 65s - 2s/step - accuracy: 0.9965 - loss: 0.0536 - val_accuracy: 0.8505 - val_loss: 0.4025 - learning_rate: 5.0000e-05
# Epoch 48/200
#
# Epoch 48: val_accuracy did not improve from 0.87850
# 27/27 - 83s - 3s/step - accuracy: 0.9918 - loss: 0.0578 - val_accuracy: 0.8505 - val_loss: 0.4067 - learning_rate: 5.0000e-05
# Epoch 49/200
#
# Epoch 49: val_accuracy did not improve from 0.87850
# 27/27 - 67s - 2s/step - accuracy: 0.9918 - loss: 0.0539 - val_accuracy: 0.8692 - val_loss: 0.3843 - learning_rate: 5.0000e-05
# Epoch 50/200
#
# Epoch 50: val_accuracy did not improve from 0.87850
# 27/27 - 64s - 2s/step - accuracy: 0.9895 - loss: 0.0638 - val_accuracy: 0.8692 - val_loss: 0.3781 - learning_rate: 5.0000e-05
# Epoch 51/200
#
# Epoch 51: val_accuracy did not improve from 0.87850
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 27/27 - 83s - 3s/step - accuracy: 0.9895 - loss: 0.0562 - val_accuracy: 0.8505 - val_loss: 0.4178 - learning_rate: 5.0000e-05
# Epoch 52/200
#
# Epoch 52: val_accuracy did not improve from 0.87850
# 27/27 - 84s - 3s/step - accuracy: 0.9953 - loss: 0.0460 - val_accuracy: 0.8598 - val_loss: 0.3996 - learning_rate: 2.5000e-05
# Epoch 53/200
#
# Epoch 53: val_accuracy did not improve from 0.87850
# 27/27 - 81s - 3s/step - accuracy: 0.9918 - loss: 0.0489 - val_accuracy: 0.8692 - val_loss: 0.3914 - learning_rate: 2.5000e-05
# Epoch 54/200
#
# Epoch 54: val_accuracy did not improve from 0.87850
# 27/27 - 82s - 3s/step - accuracy: 0.9930 - loss: 0.0426 - val_accuracy: 0.8318 - val_loss: 0.4022 - learning_rate: 2.5000e-05
# Epoch 55/200
#
# Epoch 55: val_accuracy did not improve from 0.87850
# 27/27 - 68s - 3s/step - accuracy: 0.9965 - loss: 0.0442 - val_accuracy: 0.8598 - val_loss: 0.4091 - learning_rate: 2.5000e-05
# Epoch 56/200
#
# Epoch 56: val_accuracy did not improve from 0.87850
# 27/27 - 66s - 2s/step - accuracy: 0.9942 - loss: 0.0421 - val_accuracy: 0.8692 - val_loss: 0.3947 - learning_rate: 2.5000e-05
# Epoch 57/200
#
# Epoch 57: val_accuracy did not improve from 0.87850
# 27/27 - 68s - 3s/step - accuracy: 0.9965 - loss: 0.0408 - val_accuracy: 0.8692 - val_loss: 0.4185 - learning_rate: 2.5000e-05
# Epoch 58/200
#
# Epoch 58: val_accuracy did not improve from 0.87850
# 27/27 - 80s - 3s/step - accuracy: 0.9977 - loss: 0.0389 - val_accuracy: 0.8505 - val_loss: 0.3916 - learning_rate: 2.5000e-05
# Epoch 59/200
#
# Epoch 59: val_accuracy did not improve from 0.87850
# 27/27 - 83s - 3s/step - accuracy: 0.9965 - loss: 0.0359 - val_accuracy: 0.8598 - val_loss: 0.4105 - learning_rate: 2.5000e-05
# Epoch 60/200
#
# Epoch 60: val_accuracy did not improve from 0.87850
# 27/27 - 68s - 3s/step - accuracy: 0.9907 - loss: 0.0378 - val_accuracy: 0.8598 - val_loss: 0.4220 - learning_rate: 2.5000e-05
# Epoch 61/200
#
# Epoch 61: val_accuracy did not improve from 0.87850
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 27/27 - 67s - 2s/step - accuracy: 0.9977 - loss: 0.0304 - val_accuracy: 0.8411 - val_loss: 0.4170 - learning_rate: 2.5000e-05
# Epoch 61: early stopping
# --- Training finished ---
# ✅ Final Test Accuracy: 84.11%

# %% [markdown]
# ## Enhance data augmentation
#
# ### Subtask:
# Implement additional audio augmentation techniques to increase the diversity and size of the training dataset. This could include techniques like adding background noise, changing speed, or applying spectral augmentations.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# Predictions
y_pred = model.predict(X_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=le.classes_,
            yticklabels=le.classes_,
            cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (EMO-DB)")
plt.show()

# Training vs Validation Accuracy/Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step

# %%
import librosa.display

# Pick a random sample
sample_audio = X_train_raw[0]
plt.figure(figsize=(12, 4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(sample_audio)), ref=np.max)
librosa.display.specshow(D, sr=initial_sample_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (log scale)")
plt.show()

# MFCC Heatmap
mfcc = librosa.feature.mfcc(y=sample_audio, sr=initial_sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfcc, x_axis='time', cmap='viridis')
plt.colorbar()
plt.title("MFCC Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Improve the accuracy of the model to 94% by adjusting hyperparameters and enhancing data augmentation.

# %% [markdown]
# ## Adjust hyperparameters
#
# ### Subtask:
# Modify learning rate, dropout, and potentially add more epochs or adjust learning rate reduction parameters.

# %% [markdown]
# **Reasoning**:
# Reviewing the current hyperparameters and model definition to identify areas for adjustment based on the instructions. I will focus on modifying the learning rate, dropout, and potentially increasing epochs or adjusting learning rate reduction parameters. I will start by slightly increasing the epochs, reducing the initial learning rate, and adjusting the Rlrp callback. I will then adjust dropout rates in the model definition.
